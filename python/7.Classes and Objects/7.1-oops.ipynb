# %% [markdown]
# Object-Oriented Programming is a programming paradigm that uses"objects" to design applications and computer programs. OOP allows for modelling real-world scenarios using classes and objects.

# %%
## A class is a blueprint for creating the objects.
class Car:
    pass 
audi = Car()
bmw = Car()
print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
### Instance Variables and methods 
class Dog:
    ## Constructor 
    def __init__(self,name,age):
        self.name = name 
        self.age = age
## Create objects 
dog1 = Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2 = Dog("Lucy",4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
## Define a class with instance methods 
class Dog:
    def __init__(self,name,age):
        self.name = name 
        self.age = age 
    def bark(self):
        print(f"{self.name} says woof")
dog1 = Dog("Buddy",3)
dog1.bark()
dog2 = Dog("lucy",4)
dog2.bark()
# Out:
# Buddy says woof
# lucy says woof

# %%
### Modeling a Bank Account

## Define a class for the bank account 
class BankAccount:
    def __init__(self,owner,balance):
        self.owner=owner
        self.balance = balance
    
    def deposite(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. New Balance is {self.balance} ")
    
    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient Funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn.New balance is {self.balance}")
    def get_balance(self):
        return self.balance

## Create an account 
account = BankAccount("Amiya Ranjan Swain",10000)
print(account.balance)
# Out:
# 10000

# %%
account.deposite(500)
# Out:
# 500 is deposited. New Balance is 10500

# %%
account.withdraw(700)
# Out:
# 700 is withdrawn.New balance is 9800

# %%
print(account.get_balance())
# Out:
# 9800
