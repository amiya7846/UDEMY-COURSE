# %% [markdown]
# ### Lambda Function in Python
#
# - Lambda functions are small anonymous functions defined using the lambda keyword. They can have any number of arguments but only one expression. They are commonly used for short operations or as arguments to higher-order functions.

# %%
# Syntax 
lambda arguments: expression

# %%
def addition(a,b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition = lambda a,b:a+b
type(addition)
print(addition(5,6))
# Out:
# 11

# %%
def even(num):
    if num%2 ==0:
        return True
even(24)
# Out:
# True

# %%
even1 = lambda num:num%2==0
even1(42)
# Out:
# True

# %%
def addition (x,y,z):
    return x+y+z

addition(12,34,54)
# Out:
# 100

# %%
addition1 = lambda x,y,z:x+y+z
addition1(12,45,21)
# Out:
# 78

# %%
## map()- It applies the function to all the items in a list.
numbers = [1,2,3,4,5]
def square(number):
    return number**2
square (2)
# Out:
# 4

# %%
list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
map(lambda x:x**2,numbers) ## here it shows the file location where it was saved in the memory.
