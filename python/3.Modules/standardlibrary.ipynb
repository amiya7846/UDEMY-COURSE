# %%
import array
arr= array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math 
print(math.sqrt(25))
print(math.pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['banana','apple','cherry']))
# Out:
# 2
# cherry

# %%
## File and Directory Access
import os
print(os.getcwd())
# Out:
# d:\UDEMY\python\Modules

# %%
os.mkdir('test_dir') ## new folder named test_dir created

# %%
## High level operations on files and collection of files 
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data serialization
import json
data = {'name':'Amiya','age':20}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

past_data = json.loads(json_str)
print(past_data)
print(type(past_data))
# Out:
# {"name": "Amiya", "age": 20}
# <class 'str'>
# {'name': 'Amiya', 'age': 20}
# <class 'dict'>

# %%
import csv
with open('example.csv',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Amiya',20])

with open('example.csv',mode = 'r') as file:
    reader = csv.reader(file) 
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Amiya', '20']

# %%
from datetime import datetime,timedelta
now = datetime.now()
print(now)

yesterday = now-timedelta(days = 1)
print(yesterday)
# Out:
# 2026-07-16 15:58:00.337001
# 2026-07-15 15:58:00.337001

# %%
## Time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1784197741.4614046
# 1784197743.4625683

# %%
## Regular Expression
import re
pattern = r'\d+'
text = 'There are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
