# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
a = input("Enter a number: ")
print("You entered:", a)
# Out:
# You entered: 45

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
a = int(input("Enter a number: "))
if a > 0:
    print("The number is positive.")
elif a < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# The number is negative.

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = int(input("Enter the first number."))
num2 = int(input("Enter the second number."))
num3 = int(input("Enter the third number."))
if num1 >= num2 and num1 >= num3:
    print("The largest number is:", num1)
elif num2 >= num1 and num2 >= num3:
    print("The largest number is:", num2)
else:
    print("The largest number is:", num3)
# Out:
# The largest number is: 78

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def factorial (n):
    if n < 0:
        return "factorial is not defined for negetive numbers."
    elif n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n-1)   
n = int(input("Enter a number: "))
print("The factorial of ", n, "is", factorial(n))
# Out:
# The factorial of  5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
int_var = 10
float_var = 3.14
str_var = "Hello World"
bool_var = True
print(type(int_var))
print(type(float_var))
print(type(str_var))
print(type(bool_var))
print("Integer variables", int_var)
print("Float variables", float_var)
print("String variables", str_var)
print("Boolean variables", bool_var)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# Integer variables 10
# Float variables 3.14
# String variables Hello World
# Boolean variables True

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 8
b = 5
print(f"before swapping: a = {a}, b = {b}")
a, b = b, a
print(f"After swapping: a = {a}, b = {b}")
# Out:
# before swapping: a = 8, b = 5
# After swapping: a = 5, b = 8

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
a = float(input("Enter in celsius:"))
fahrenheit = (a * 9/5) + 32
print(f"{a} degree celsius is equal to {fahrenheit} degree fahrenheit.")
# Out:
# 32.0 degree celsius is equal to 89.6 degree fahrenheit.

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = input("Enter the first string:")
str2 = input("Enter the second string:")
concatenataed_str = str1 + " " + str2
print("The concatenated string is:", concatenataed_str)
# Out:
# The concatenated string is: amiya swain

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var = 450.2
if isinstance(var, float):
    print("The variable is a float type.")
else:
    print("The variable is not a float type.")
# Out:
# The variable is a float type.

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = float(input("Enter the first number:"))
num2 = float(input("Enter the second number:"))
sum = num1 + num2
print("The sum of the two numbers is:", sum)
substraction = num1 - num2 
print("The substraction of the two numbers is:", substraction)
product = num1 * num2 
print("The product of the two numbers is:", product)
division = num1 / num2 
print("The division of the two numbers is:", division)
# Out:
# The sum of the two numbers is: 90.0
# The substraction of the two numbers is: 0.0
# The product of the two numbers is: 2025.0
# The division of the two numbers is: 1.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number:"))
if num1 > num2:
    print(f"{num1} is greater than {num2}.")
elif num1 < num2:
    print(f"{num1} is less than {num2}.")
elif num1 == num2:
    print(f"{num1} is equal to {num2}.")    
elif num1 != num2:
    print(f"{num1} is not equal to {num2}.")
# Out:
# 45 is equal to 45.

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False
print(f"True and False ",{a and b})
print(f"True and Flase", {a or b})
print(f"not True", {not a})
# Out:
# True and False  {False}
# True and Flase {True}
# not True {False}

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("Enter a number:"))
square = num ** 2
print(f"The square of {num} is {square}.")
# Out:
# The square of 45 is 2025.

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input ("Enter a number: "))
if num % 2 == 0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
def natural_numbers_sum(n):
    if n <= 0:
        return 0
    else:
        return n + natural_numbers_sum(n - 1)
num = int(input("Enter a positive integer: "))
print("The sum of the first", num, "natural numbers is:", natural_numbers_sum(num))
# Out:
# The sum of the first 5 natural numbers is: 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter the year:"))
if (year % 4 == 0 and year % 100 == 0) or (year % 400 == 0):
    print(f"{year} is a leap year")
else:
    print("It is not a leap year")
# Out:
# 2000 is a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str = input("Enter the string:")
str = str[ ::-1]
print("The reversed string is:", str)
# Out:
# The reversed string is: ayima

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str = input ("Enter the string:")
if str == str [ ::-1]:
    print("The string is palindrome.")
else:
    print("The string is not palindrome.")
# Out:
# The string is palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# Sorted list: [45, 46, 454, 521, 653, 659, 698, 1545, 1545, 3256, 15485, 24549, 54524, 61659, 124578, 168461, 454654, 546649, 665489, 1548579, 2165695, 16556168, 46456489, 46468953, 86435468465]
